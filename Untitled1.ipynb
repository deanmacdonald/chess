# %%
Chess Game
# Out:
#   Cell In[1], line 1
#     Chess Game
#           ^
# SyntaxError: invalid syntax

# %%
Chess Game
# Out:
#   Cell In[1], line 1
#     Chess Game
#           ^
# SyntaxError: invalid syntax
